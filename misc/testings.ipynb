# %%
import os
os.chdir('../preprocessing/')
import pipe
os.chdir('../misc/')
import pandas as pd

# %%
def hot_encode_categorical(df):
    for column in df:
        print(df[column].dtypes)
        if df[column].dtypes == 'category':
            df[column] = df[column].astype('category').cat.codes
    return df

# %%
df = pipe.preprocessing_pipe(hot_encode_cat = False)

# %%
print(df.dtypes)

for column in df.columns:
        print(df[column].dtypes)
        
        if df[column].dtypes == "category":
            print('boo')
            df[column] = df[column].cat.codes
            print(df[column])
# Out:
# gender                                             category
# race                                               category
# loc                                                category
# cat                                                category
# specific_diagnosis                                 category
# ac_abn_od_cells                                    category
# ac_abn_os_cells                                    category
# vit_abn_od_cells                                   category
# vit_abn_os_cells                                   category
# vit_abn_od_haze                                    category
# vit_abn_os_haze                                    category
# calcium                                             float64
# lactate_dehydrogenase                                 Int64
# c-reactive_protein,_normal_and_high_sensitivity     float64
# wbc                                                 float64
# rbc                                                 float64
# hemoglobin                                          float64
# hematocrit                                          float64
# mcv                                                 float64
# mch                                                 float64
# mchc                                                float64
# rdw                                                 float64
# platelet_count                                        Int64
# neutrophil_%                                        float64
# lymphocytes_%                                       float64
# angiotensin_conv#enzyme                             float64
# lysozyme,_plasma                                    float64
# anti-ccp_ab                                         float64
# anti-ena_screen                                     float64
# antinuclear_antibody                                float64
# complement_c3                                       float64
# complement_c4                                       float64
# dna_double-stranded_ab                              float64
# rheumatoid_factor                                     Int64
# hbc__ab                                              object
# hbs__ag                                              object
# hcv__ab                                              object
# dtype: object
# category
# boo
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1070    1
# 1071    1
# 1072    0
# 1073    0
# 1074    1
# Name: gender, Length: 1074, dtype: int8
# category
# boo
# 0       2
# 1       2
# 2       5
# 3       5
# 4       6
#        ..
# 1070    1
# 1071    6
# 1072    6
# 1073    1
# 1074    5
# Name: race, Length: 1074, dtype: int8
# category
# boo
# 0       0
# 1       1
# 2       2
# 3       0
# 4       0
#        ..
# 1070    2
# 1071    1
# 1072    3
# 1073    3
# 1074    3
# Name: loc, Length: 1074, dtype: int8
# category
# boo
# 0       4
# 1       0
# 2       6
# 3       0
# 4       0
#        ..
# 1070    1
# 1071    0
# 1072    1
# 1073    7
# 1074    4
# Name: cat, Length: 1074, dtype: int8
# category
# boo
# 0        4
# 1       11
# 2       17
# 3        4
# 4        4
#         ..
# 1070    15
# 1071    11
# 1072    14
# 1073    18
# 1074     9
# Name: specific_diagnosis, Length: 1074, dtype: int8
# category
# boo
# 0       0
# 1       3
# 2       1
# 3       0
# 4       0
#        ..
# 1070    0
# 1071    0
# 1072    0
# 1073    0
# 1074    0
# Name: ac_abn_od_cells, Length: 1074, dtype: int8
# category
# boo
# 0       0
# 1       3
# 2       1
# 3       0
# 4       0
#        ..
# 1070    0
# 1071    2
# 1072    0
# 1073    0
# 1074    0
# Name: ac_abn_os_cells, Length: 1074, dtype: int8
# category
# boo
# 0       0
# 1       3
# 2       2
# 3       0
# 4       0
#        ..
# 1070    0
# 1071    0
# 1072    0
# 1073    0
# 1074    0
# Name: vit_abn_od_cells, Length: 1074, dtype: int8
# category
# boo
# 0       1
# 1       3
# 2       2
# 3       0
# 4       0
#        ..
# 1070    0
# 1071    3
# 1072    2
# 1073    0
# 1074    0
# Name: vit_abn_os_cells, Length: 1074, dtype: int8
# category
# boo
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1070    0
# 1071    0
# 1072    0
# 1073    0
# 1074    0
# Name: vit_abn_od_haze, Length: 1074, dtype: int8
# category
# boo
# 0       0
# 1       2
# 2       0
# 3       0
# 4       0
#        ..
# 1070    0
# 1071    3
# 1072    2
# 1073    0
# 1074    0
# Name: vit_abn_os_haze, Length: 1074, dtype: int8
# float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-0b2e36811e52> in <module>
#       4         print(df[column].dtypes)
#       5
# ----> 6         if df[column].dtypes == "category":
#       7             print('boo')
#       8             df[column] = df[column].cat.codes
#
# TypeError: data type 'category' not understood
